# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("Weather_Dataset.csv")

# %%
df=dataset

# %%
#convert the time column in to datetime mode
df['time']=pd.to_datetime(df['time'])

# %%
#Create a new column named "Year"
df['year']=df['time'].dt.year

# %%
#Create a new column named "month"
df['month']=df['time'].dt.month

# %%
df
# Out:
#              time  weathercode  temperature_2m_max  temperature_2m_min  \
# 0      2010-01-01            2                30.0                22.7
# 1      2010-01-02           51                29.9                23.5
# 2      2010-01-03           51                29.5                23.2
# 3      2010-01-04            2                28.9                21.9
# 4      2010-01-05            1                28.1                21.3
# ...           ...          ...                 ...                 ...
# 147475 2023-06-13           63                29.2                24.7
# 147476 2023-06-14           61                29.1                25.4
# 147477 2023-06-15           51                29.8                25.5
# 147478 2023-06-16           53                30.5                25.5
# 147479 2023-06-17           51                29.6                25.2
#
#         temperature_2m_mean  apparent_temperature_max  \
# 0                      26.1                      34.4
# 1                      26.2                      33.8
# 2                      26.0                      34.3
# 3                      25.3                      31.6
# 4                      24.5                      30.1
# ...                     ...                       ...
# 147475                 26.6                      35.4
# 147476                 26.9                      34.3
# 147477                 27.3                      36.6
# 147478                 27.7                      36.2
# 147479                 26.9                      35.9
#
#         apparent_temperature_min  apparent_temperature_mean           sunrise  \
# 0                           25.2                       29.2  2010-01-01T00:52
# 1                           26.2                       29.8  2010-01-02T00:52
# 2                           26.3                       29.9  2010-01-03T00:53
# 3                           23.4                       27.8  2010-01-04T00:53
# 4                           23.1                       26.1  2010-01-05T00:53
# ...                          ...                        ...               ...
# 147475                      29.2                       31.6  2023-06-13T00:24
# 147476                      30.4                       32.0  2023-06-14T00:24
# 147477                      30.7                       32.7  2023-06-15T00:24
# 147478                      30.1                       32.4  2023-06-16T00:25
# 147479                      30.1                       32.0  2023-06-17T00:25
#
#                   sunset  ...  windgusts_10m_max  winddirection_10m_dominant  \
# 0       2010-01-01T12:35  ...               27.4                          20
# 1       2010-01-02T12:36  ...               27.0                          24
# 2       2010-01-03T12:36  ...               27.4                          16
# 3       2010-01-04T12:37  ...               34.6                         356
# 4       2010-01-05T12:37  ...               37.1                         355
# ...                  ...  ...                ...                         ...
# 147475  2023-06-13T12:55  ...               43.6                         229
# 147476  2023-06-14T12:55  ...               40.0                         224
# 147477  2023-06-15T12:56  ...               32.4                         218
# 147478  2023-06-16T12:56  ...               41.8                         236
# 147479  2023-06-17T12:56  ...               37.8                         231
#
#         et0_fao_evapotranspiration  latitude  longitude  elevation    country  \
# 0                             4.58  7.000000  79.899994       16.0  Sri Lanka
# 1                             3.84  7.000000  79.899994       16.0  Sri Lanka
# 2                             3.65  7.000000  79.899994       16.0  Sri Lanka
# 3                             3.79  7.000000  79.899994       16.0  Sri Lanka
# 4                             4.97  7.000000  79.899994       16.0  Sri Lanka
# ...                            ...       ...        ...        ...        ...
# 147475                        3.41  6.900002  80.000000       20.0  Sri Lanka
# 147476                        3.00  6.900002  80.000000       20.0  Sri Lanka
# 147477                        3.21  6.900002  80.000000       20.0  Sri Lanka
# 147478                        3.97  6.900002  80.000000       20.0  Sri Lanka
# 147479                        2.95  6.900002  80.000000       20.0  Sri Lanka
#
#            city  year  month
# 0       Colombo  2010      1
# 1       Colombo  2010      1
# 2       Colombo  2010      1
# 3       Colombo  2010      1
# 4       Colombo  2010      1
# ...         ...   ...    ...
# 147475  Oruwala  2023      6
# 147476  Oruwala  2023      6
# 147477  Oruwala  2023      6
# 147478  Oruwala  2023      6
# 147479  Oruwala  2023      6
#
# [147480 rows x 26 columns]

# %%
# Check for 0 values in each column
zero_values = (df == 0).sum()

# Display the count of 0 values for each column
print(zero_values)
# Out:
# time                               0
# weathercode                     1024
# temperature_2m_max                 0
# temperature_2m_min                 0
# temperature_2m_mean                0
# apparent_temperature_max           0
# apparent_temperature_min           0
# apparent_temperature_mean          0
# sunrise                            0
# sunset                             0
# shortwave_radiation_sum            0
# precipitation_sum              26727
# rain_sum                       26727
# snowfall_sum                  147480
# precipitation_hours            26727
# windspeed_10m_max                  0
# windgusts_10m_max                  0
# winddirection_10m_dominant       126
# et0_fao_evapotranspiration         0
# latitude                           0
# longitude                          0
# elevation                       9832
# country                            0
# city                               0
# year                               0
# month                              0
# dtype: int64

# %%
# Replace 0 values with the mean of each column
df.replace(0, df.mean(), inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15128\1261378283.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.replace(0, df.mean(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_15128\1261378283.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.replace(0, df.mean(), inplace=True)

# %%
print(df)
# Out:
#              time  weathercode  temperature_2m_max  temperature_2m_min  \
# 0      2010-01-01          2.0                30.0                22.7
# 1      2010-01-02         51.0                29.9                23.5
# 2      2010-01-03         51.0                29.5                23.2
# 3      2010-01-04          2.0                28.9                21.9
# 4      2010-01-05          1.0                28.1                21.3
# ...           ...          ...                 ...                 ...
# 147475 2023-06-13         63.0                29.2                24.7
# 147476 2023-06-14         61.0                29.1                25.4
# 147477 2023-06-15         51.0                29.8                25.5
# 147478 2023-06-16         53.0                30.5                25.5
# 147479 2023-06-17         51.0                29.6                25.2
#
#         temperature_2m_mean  apparent_temperature_max  \
# 0                      26.1                      34.4
# 1                      26.2                      33.8
# 2                      26.0                      34.3
# 3                      25.3                      31.6
# 4                      24.5                      30.1
# ...                     ...                       ...
# 147475                 26.6                      35.4
# 147476                 26.9                      34.3
# 147477                 27.3                      36.6
# 147478                 27.7                      36.2
# 147479                 26.9                      35.9
#
#         apparent_temperature_min  apparent_temperature_mean           sunrise  \
# 0                           25.2                       29.2  2010-01-01T00:52
# 1                           26.2                       29.8  2010-01-02T00:52
# 2                           26.3                       29.9  2010-01-03T00:53
# 3                           23.4                       27.8  2010-01-04T00:53
# 4                           23.1                       26.1  2010-01-05T00:53
# ...                          ...                        ...               ...
# 147475                      29.2                       31.6  2023-06-13T00:24
# 147476                      30.4                       32.0  2023-06-14T00:24
# 147477                      30.7                       32.7  2023-06-15T00:24
# 147478                      30.1                       32.4  2023-06-16T00:25
# 147479                      30.1                       32.0  2023-06-17T00:25
#
#                   sunset  ...  windgusts_10m_max  winddirection_10m_dominant  \
# 0       2010-01-01T12:35  ...               27.4                        20.0
# 1       2010-01-02T12:36  ...               27.0                        24.0
# 2       2010-01-03T12:36  ...               27.4                        16.0
# 3       2010-01-04T12:37  ...               34.6                       356.0
# 4       2010-01-05T12:37  ...               37.1                       355.0
# ...                  ...  ...                ...                         ...
# 147475  2023-06-13T12:55  ...               43.6                       229.0
# 147476  2023-06-14T12:55  ...               40.0                       224.0
# 147477  2023-06-15T12:56  ...               32.4                       218.0
# 147478  2023-06-16T12:56  ...               41.8                       236.0
# 147479  2023-06-17T12:56  ...               37.8                       231.0
#
#         et0_fao_evapotranspiration  latitude  longitude  elevation    country  \
# 0                             4.58  7.000000  79.899994       16.0  Sri Lanka
# 1                             3.84  7.000000  79.899994       16.0  Sri Lanka
# 2                             3.65  7.000000  79.899994       16.0  Sri Lanka
# 3                             3.79  7.000000  79.899994       16.0  Sri Lanka
# 4                             4.97  7.000000  79.899994       16.0  Sri Lanka
# ...                            ...       ...        ...        ...        ...
# 147475                        3.41  6.900002  80.000000       20.0  Sri Lanka
# 147476                        3.00  6.900002  80.000000       20.0  Sri Lanka
# 147477                        3.21  6.900002  80.000000       20.0  Sri Lanka
# 147478                        3.97  6.900002  80.000000       20.0  Sri Lanka
# 147479                        2.95  6.900002  80.000000       20.0  Sri Lanka
#
#            city  year  month
# 0       Colombo  2010      1
# 1       Colombo  2010      1
# 2       Colombo  2010      1
# 3       Colombo  2010      1
# 4       Colombo  2010      1
# ...         ...   ...    ...
# 147475  Oruwala  2023      6
# 147476  Oruwala  2023      6
# 147477  Oruwala  2023      6
# 147478  Oruwala  2023      6
# 147479  Oruwala  2023      6
#
# [147480 rows x 26 columns]

# %%
# Select columns for which you want to detect and remove outliers
columns_of_interest = ['shortwave_radiation_sum', 'rain_sum']

# Calculate the first quartile (Q1) and third quartile (Q3) for each column
Q1 = df.quantile(0.25)
Q3 = df[columns_of_interest].quantile(0.75)

# Calculate the IQR for each column
IQR = Q3 - Q1

# Define a threshold for considering values as outliers (e.g., 1.5 times IQR)
threshold = 1.5

# Create a boolean mask for outliers
outliers_mask = ((df[columns_of_interest] < (Q1 - threshold * IQR)) |
                 (df[columns_of_interest] > (Q3 + threshold * IQR))).any(axis=1)

# Check for 0 values in each column
zero_values = (df[outliers_mask]).sum()

# Display the count of 0 values for each column
print(zero_values)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15128\3244358845.py:5: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# C:\Users\User\AppData\Local\Temp\ipykernel_15128\3244358845.py:15: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers_mask = ((df[columns_of_interest] < (Q1 - threshold * IQR)) |
# C:\Users\User\AppData\Local\Temp\ipykernel_15128\3244358845.py:16: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   (df[columns_of_interest] > (Q3 + threshold * IQR))).any(axis=1)
# weathercode                                                            960639.0
# temperature_2m_max                                                     422737.5
# temperature_2m_min                                                     360076.3
# temperature_2m_mean                                                    383716.0
# apparent_temperature_max                                               499327.8
# apparent_temperature_min                                               420148.5
# apparent_temperature_mean                                              450437.8
# sunrise                       2010-01-30T00:592010-02-01T00:592010-02-18T00:...
# sunset                        2010-01-30T12:482010-02-01T12:492010-02-18T12:...
# shortwave_radiation_sum                                               188549.25
# precipitation_sum                                                 419189.742209
# rain_sum                                                          419189.742209
# snowfall_sum                                                                0.0
# precipitation_hours                                               278300.588141
# windspeed_10m_max                                                      219619.3
# windgusts_10m_max                                                      516918.4
# winddirection_10m_dominant                                       2829238.632493
# et0_fao_evapotranspiration                                             38763.78
# latitude                                                          107908.013714
# longitude                                                        1228236.513674
# elevation                                                        2001445.866667
# country                       Sri LankaSri LankaSri LankaSri LankaSri LankaS...
# city                          ColomboColomboColomboColomboColomboColomboColo...
# year                                                                   30874061
# month                                                                    120958
# dtype: object
# C:\Users\User\AppData\Local\Temp\ipykernel_15128\3244358845.py:19: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   zero_values = (df[outliers_mask]).sum()

# %%
# Select columns for which you want to detect and remove outliers
columns_of_interest = ['shortwave_radiation_sum', 'rain_sum','temperature_2m_max','temperature_2m_min','temperature_2m_mean','apparent_temperature_max','apparent_temperature_min',
'apparent_temperature_mean','shortwave_radiation_sum','precipitation_sum','rain_sum','precipitation_hours','windspeed_10m_max','windgusts_10m_max','winddirection_10m_dominant','et0_fao_evapotranspiration',
'latitude','longitude','elevation']

# Calculate the first quartile (Q1) and third quartile (Q3) for each column
Q1 = df[columns_of_interest].quantile(0.25)
Q3 = df[columns_of_interest].quantile(0.75)

# Calculate the IQR for each column
IQR = Q3 - Q1

# Define a threshold for considering values as outliers (e.g., 1.5 times IQR)
threshold = 1.5

# Create a boolean mask for outliers
outliers_mask = ((df[columns_of_interest] < (Q1 - threshold * IQR)) |
                 (df[columns_of_interest] > (Q3 + threshold * IQR))).any(axis=1)

# Remove rows with outliers
weather_no_outliers = df[~outliers_mask]

# %%
weather_no_outliers
# Out:
#              time  weathercode  temperature_2m_max  temperature_2m_min  \
# 0      2010-01-01          2.0                30.0                22.7
# 1      2010-01-02         51.0                29.9                23.5
# 2      2010-01-03         51.0                29.5                23.2
# 3      2010-01-04          2.0                28.9                21.9
# 4      2010-01-05          1.0                28.1                21.3
# ...           ...          ...                 ...                 ...
# 147473 2023-06-11         61.0                28.8                25.2
# 147476 2023-06-14         61.0                29.1                25.4
# 147477 2023-06-15         51.0                29.8                25.5
# 147478 2023-06-16         53.0                30.5                25.5
# 147479 2023-06-17         51.0                29.6                25.2
#
#         temperature_2m_mean  apparent_temperature_max  \
# 0                      26.1                      34.4
# 1                      26.2                      33.8
# 2                      26.0                      34.3
# 3                      25.3                      31.6
# 4                      24.5                      30.1
# ...                     ...                       ...
# 147473                 26.9                      35.1
# 147476                 26.9                      34.3
# 147477                 27.3                      36.6
# 147478                 27.7                      36.2
# 147479                 26.9                      35.9
#
#         apparent_temperature_min  apparent_temperature_mean           sunrise  \
# 0                           25.2                       29.2  2010-01-01T00:52
# 1                           26.2                       29.8  2010-01-02T00:52
# 2                           26.3                       29.9  2010-01-03T00:53
# 3                           23.4                       27.8  2010-01-04T00:53
# 4                           23.1                       26.1  2010-01-05T00:53
# ...                          ...                        ...               ...
# 147473                      30.4                       32.2  2023-06-11T00:24
# 147476                      30.4                       32.0  2023-06-14T00:24
# 147477                      30.7                       32.7  2023-06-15T00:24
# 147478                      30.1                       32.4  2023-06-16T00:25
# 147479                      30.1                       32.0  2023-06-17T00:25
#
#                   sunset  ...  windgusts_10m_max  winddirection_10m_dominant  \
# 0       2010-01-01T12:35  ...               27.4                        20.0
# 1       2010-01-02T12:36  ...               27.0                        24.0
# 2       2010-01-03T12:36  ...               27.4                        16.0
# 3       2010-01-04T12:37  ...               34.6                       356.0
# 4       2010-01-05T12:37  ...               37.1                       355.0
# ...                  ...  ...                ...                         ...
# 147473  2023-06-11T12:55  ...               37.8                       226.0
# 147476  2023-06-14T12:55  ...               40.0                       224.0
# 147477  2023-06-15T12:56  ...               32.4                       218.0
# 147478  2023-06-16T12:56  ...               41.8                       236.0
# 147479  2023-06-17T12:56  ...               37.8                       231.0
#
#         et0_fao_evapotranspiration  latitude  longitude  elevation    country  \
# 0                             4.58  7.000000  79.899994       16.0  Sri Lanka
# 1                             3.84  7.000000  79.899994       16.0  Sri Lanka
# 2                             3.65  7.000000  79.899994       16.0  Sri Lanka
# 3                             3.79  7.000000  79.899994       16.0  Sri Lanka
# 4                             4.97  7.000000  79.899994       16.0  Sri Lanka
# ...                            ...       ...        ...        ...        ...
# 147473                        2.99  6.900002  80.000000       20.0  Sri Lanka
# 147476                        3.00  6.900002  80.000000       20.0  Sri Lanka
# 147477                        3.21  6.900002  80.000000       20.0  Sri Lanka
# 147478                        3.97  6.900002  80.000000       20.0  Sri Lanka
# 147479                        2.95  6.900002  80.000000       20.0  Sri Lanka
#
#            city  year  month
# 0       Colombo  2010      1
# 1       Colombo  2010      1
# 2       Colombo  2010      1
# 3       Colombo  2010      1
# 4       Colombo  2010      1
# ...         ...   ...    ...
# 147473  Oruwala  2023      6
# 147476  Oruwala  2023      6
# 147477  Oruwala  2023      6
# 147478  Oruwala  2023      6
# 147479  Oruwala  2023      6
#
# [88747 rows x 26 columns]

# %%
#DROP irrelevant features(columns)
# List of columns to drop
columns_to_drop = ['time', 'sunrise','rain_sum', 'sunset','snowfall_sum','country','city']

# Drop the specified columns
weather_no_outliers.drop(columns=columns_to_drop, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15128\445160577.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather_no_outliers.drop(columns=columns_to_drop, inplace=True)

# %%
weather_no_outliers
# Out:
#         weathercode  temperature_2m_max  temperature_2m_min  \
# 0               2.0                30.0                22.7
# 1              51.0                29.9                23.5
# 2              51.0                29.5                23.2
# 3               2.0                28.9                21.9
# 4               1.0                28.1                21.3
# ...             ...                 ...                 ...
# 147473         61.0                28.8                25.2
# 147476         61.0                29.1                25.4
# 147477         51.0                29.8                25.5
# 147478         53.0                30.5                25.5
# 147479         51.0                29.6                25.2
#
#         temperature_2m_mean  apparent_temperature_max  \
# 0                      26.1                      34.4
# 1                      26.2                      33.8
# 2                      26.0                      34.3
# 3                      25.3                      31.6
# 4                      24.5                      30.1
# ...                     ...                       ...
# 147473                 26.9                      35.1
# 147476                 26.9                      34.3
# 147477                 27.3                      36.6
# 147478                 27.7                      36.2
# 147479                 26.9                      35.9
#
#         apparent_temperature_min  apparent_temperature_mean  \
# 0                           25.2                       29.2
# 1                           26.2                       29.8
# 2                           26.3                       29.9
# 3                           23.4                       27.8
# 4                           23.1                       26.1
# ...                          ...                        ...
# 147473                      30.4                       32.2
# 147476                      30.4                       32.0
# 147477                      30.7                       32.7
# 147478                      30.1                       32.4
# 147479                      30.1                       32.0
#
#         shortwave_radiation_sum  precipitation_sum  precipitation_hours  \
# 0                         20.92           5.975637             8.762524
# 1                         17.71           0.100000             1.000000
# 2                         17.76           0.600000             3.000000
# 3                         16.50           5.975637             8.762524
# 4                         23.61           5.975637             8.762524
# ...                         ...                ...                  ...
# 147473                    14.88           4.900000            18.000000
# 147476                    14.97           7.300000            19.000000
# 147477                    15.89           3.200000            17.000000
# 147478                    19.21           5.600000            24.000000
# 147479                    14.80           5.000000            23.000000
#
#         windspeed_10m_max  windgusts_10m_max  winddirection_10m_dominant  \
# 0                    11.7               27.4                        20.0
# 1                    13.0               27.0                        24.0
# 2                    12.3               27.4                        16.0
# 3                    17.0               34.6                       356.0
# 4                    18.7               37.1                       355.0
# ...                   ...                ...                         ...
# 147473               13.6               37.8                       226.0
# 147476               16.4               40.0                       224.0
# 147477               12.6               32.4                       218.0
# 147478               20.5               41.8                       236.0
# 147479               16.3               37.8                       231.0
#
#         et0_fao_evapotranspiration  latitude  longitude  elevation  year  \
# 0                             4.58  7.000000  79.899994       16.0  2010
# 1                             3.84  7.000000  79.899994       16.0  2010
# 2                             3.65  7.000000  79.899994       16.0  2010
# 3                             3.79  7.000000  79.899994       16.0  2010
# 4                             4.97  7.000000  79.899994       16.0  2010
# ...                            ...       ...        ...        ...   ...
# 147473                        2.99  6.900002  80.000000       20.0  2023
# 147476                        3.00  6.900002  80.000000       20.0  2023
# 147477                        3.21  6.900002  80.000000       20.0  2023
# 147478                        3.97  6.900002  80.000000       20.0  2023
# 147479                        2.95  6.900002  80.000000       20.0  2023
#
#         month
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 147473      6
# 147476      6
# 147477      6
# 147478      6
# 147479      6
#
# [88747 rows x 19 columns]

# %%
# Drop the  weathercode column
weather_no_outliers.drop(columns='weathercode', inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15128\475924902.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather_no_outliers.drop(columns='weathercode', inplace=True)

# %%
#download the dataset
weather_no_outliers.to_csv("preprocessed_weather.csv", index=False)
